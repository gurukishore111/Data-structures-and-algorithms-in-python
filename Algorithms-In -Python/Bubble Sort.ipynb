# %%
def bubblesort(a):
    b=len(a)-1
    for x in range(b):
        for y in range(b-x):
            if a[y] > a[y-1]:
              a[y],a[y+1] = a[y+1],a[y]
a=[8,9,1,2,3,4]
bubblesort(a)
print(a)
# Out:
# [1, 2, 3, 8, 9, 4]
